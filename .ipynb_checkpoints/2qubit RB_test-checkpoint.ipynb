# %%
#  given list to get c , c2 c,3...
import numpy as np
import random
import pickle
import math
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %matplotlib inline
#open Cliff_indices1 put into data
with open("Cliff_indices_4.pkl", "rb") as f:  
    data = pickle.load(f)
f.close()

#open Prim put into Prim
with open("Prim_exp.pkl", "rb") as f2:  
    Prim = pickle.load(f2)
f2.close()

#open Prim_inv put into Prim_inv
with open("Inverse_of_prim.pkl", "rb") as f3:  
    Prim_inv = pickle.load(f3)
f3.close()

with open("Prim_perfect.pkl", "rb") as f4:  
    Prim_perfect = pickle.load(f4)
f4.close() 

####################################################initial state#############################################################
#given probability  NOT Probability amplitude
#[target , ud , du , dd]
e_ud=0.01                 #error probability  NOT Probability amplitude
e_du=0                  
e_dd=0

def Is_Inverse(A, B):
    if np.allclose(np.absolute(np.trace(np.dot(A, B))), 4):
        return True
    else:
        return False
    
def error_initial_state(e1,e2,e3):
    return np.matrix([[math.sqrt(1-e1*e1-e2*e2-e3*e3),math.sqrt(e1),math.sqrt(e2),math.sqrt(e3)]]).getH()
initial = error_initial_state(e_ud,e_du,e_dd)

####################################################initial state#############################################################
#############################################Randomized Benchmarking##########################################################
#given list , return s = c0*c1*c2....
def get_s(g1):               
    p = np.identity(4)                             # 計數器for p@p1@p2....
    for i in range(len(g1)):
        array = g1[i]
        for j in range(len(array)):
            p = p@Prim[array[j]]                  #s=p*p*p*p*p*p*p....
    return p

def get_s_perfect(g1):               
    p = np.identity(4)                             # 計數器for p@p1@p2....
    for i in range(len(g1)):
        array = g1[i]
        for j in range(len(array)):
            p = p@Prim_perfect[array[j]]                  #s=p*p*p*p*p*p*p....
    return p

def get_perfect_unitary(seq):                 #Get perfect gate from decomposition info. in "Cliff_indices_4.pkl"
    p = np.identity(4)                             
    for j in range(len(seq)):
        p = p@Prim_perfect[seq[j]]                  
    return p


def get_nonperfect_unitary(seq):                 #Get perfect gate from decomposition info. in "Cliff_indices_4.pkl"
    p = np.identity(4)                             
    for i in range(len(seq)):
        p = p@Prim[seq[i]]                  
    return p

#given list , return c^-1 
def c_m(c1):
    a = get_s_perfect(c1)
    for k in range(len(data)):
        b = get_perfect_unitary(data[k])
        if Is_Inverse(a, b):
            return get_nonperfect_unitary(data[k])

l1 = np.arange(1,20,1)
l2 = np.arange(20, 40, 2)
l3 = np.arange(40, 65, 5)
x = np.hstack((l1, l2, l3))

y = []
yerr = []

N = 10                                              # samples for each data point (算標準差即是使用每個data point對應的N個數據)
K = 51                                           # of S sequence 相同長度 重複取k次

for m in x:
    print("L = ", m, " is calculating...")
    results = []
    for n in range(N):
        num_uu = 0
        for i in range(K):
            print("data", n+1, "; K =", i+1)
            list2 = random.choices(data,k=m)               #data 隨便可重複取m個
            seq_k = get_s(list2)@c_m(list2)          # k_th seq
#############################################Randomized Benchmarking##########################################################
#############################################Readout##########################################################################
            e_readout=0.01
            final_prob=np.square(np.abs(seq_k@initial))
            err = final_prob[0]*e_readout
            final_prob[0] -= err   #這邊是否會造成機率不守恒? 只有uu態機率因readout減少但其他態機率沒變?
            for i in range(1, 4): final_prob[i] += err/3
            uu_count=[1,0,0,0]
            a=random.choices(uu_count,weights=final_prob, k=1)
            num_uu=num_uu+a[0]
        results.append(num_uu/K)
    y.append(np.mean(results))
    yerr.append(np.std(results))

# Fitting function

def func(x, A, B, r):
    return A * (1 - 4/3*r)**x + B

# def func(x, A):
#     return  * (1 - 4/3*0.053)**x + 0.25

popt, pcov = curve_fit(func, x, y, p0=[1, 0, 0], bounds = (0, 1), maxfev = 5000)      
#p0 is the guess of the parameters. Guess B ~ 0 (ideally be 0.25) and r ~ 0 (no noise model now so r should be ultra low)
plt.plot(x, func(x, *popt), 'r-')
print("F_Ciff = 1 - r = ", 1-popt[2])
print("A = ", popt[0])
print("B = ", popt[1])

plt.errorbar(x, y, yerr=yerr, fmt='o', markersize=4, capsize=3)
plt.plot(x, func(x, 0.75, 0.25, 0.053), 'b-')
plt.ylim(top=1.0)
plt.xlabel("Number of Cliffords (L)")
plt.ylabel("Proj. State Prob.")
plt.title("Two-qubit RB Fitting")
# Out:
# L =  1  is calculating...
# data 1 ; K = 1
# data 1 ; K = 2
# data 1 ; K = 3
# data 1 ; K = 4
# data 1 ; K = 5
# data 1 ; K = 6
# data 1 ; K = 7
# data 1 ; K = 8
# data 1 ; K = 9
# data 1 ; K = 10
# data 1 ; K = 11
# data 1 ; K = 12
# data 1 ; K = 13
# data 1 ; K = 14
# data 1 ; K = 15
# data 1 ; K = 16
# data 1 ; K = 17
# data 1 ; K = 18
# data 1 ; K = 19
# data 1 ; K = 20
# data 1 ; K = 21
# data 1 ; K = 22
# data 1 ; K = 23
# data 1 ; K = 24
# data 1 ; K = 25
# data 1 ; K = 26
# data 1 ; K = 27
# data 1 ; K = 28
# data 1 ; K = 29
# data 1 ; K = 30
# data 1 ; K = 31
# data 1 ; K = 32
# data 1 ; K = 33
# data 1 ; K = 34
# data 1 ; K = 35
# data 1 ; K = 36
# data 1 ; K = 37
# data 1 ; K = 38
# data 1 ; K = 39
# data 1 ; K = 40
# data 1 ; K = 41
# data 1 ; K = 42
# data 1 ; K = 43
# data 1 ; K = 44
# data 1 ; K = 45
# data 1 ; K = 46
# data 1 ; K = 47
# data 1 ; K = 48
# data 1 ; K = 49
# data 1 ; K = 50
# data 1 ; K = 51
# data 2 ; K = 1
# data 2 ; K = 2
# data 2 ; K = 3
# data 2 ; K = 4
# data 2 ; K = 5
# data 2 ; K = 6
# data 2 ; K = 7
# data 2 ; K = 8
# data 2 ; K = 9
# data 2 ; K = 10
# data 2 ; K = 11
# data 2 ; K = 12
# data 2 ; K = 13
# data 2 ; K = 14
# data 2 ; K = 15
# data 2 ; K = 16
# data 2 ; K = 17
# data 2 ; K = 18
# data 2 ; K = 19
# data 2 ; K = 20
# data 2 ; K = 21
# data 2 ; K = 22
# data 2 ; K = 23
# data 2 ; K = 24
# data 2 ; K = 25
# data 2 ; K = 26
# data 2 ; K = 27
# data 2 ; K = 28
# data 2 ; K = 29
# data 2 ; K = 30
# data 2 ; K = 31
# data 2 ; K = 32
# data 2 ; K = 33
# data 2 ; K = 34
# data 2 ; K = 35
# data 2 ; K = 36
# data 2 ; K = 37
# data 2 ; K = 38
# data 2 ; K = 39
# data 2 ; K = 40
# data 2 ; K = 41
# data 2 ; K = 42
# data 2 ; K = 43
# data 2 ; K = 44
# data 2 ; K = 45
# data 2 ; K = 46
# data 2 ; K = 47
# data 2 ; K = 48
# data 2 ; K = 49
# data 2 ; K = 50
# data 2 ; K = 51
# data 3 ; K = 1
# data 3 ; K = 2
# data 3 ; K = 3
# data 3 ; K = 4
# data 3 ; K = 5
# data 3 ; K = 6
# data 3 ; K = 7
# data 3 ; K = 8
# data 3 ; K = 9
# data 3 ; K = 10
# data 3 ; K = 11
# data 3 ; K = 12
# data 3 ; K = 13
# data 3 ; K = 14
# data 3 ; K = 15
# data 3 ; K = 16
# data 3 ; K = 17
# data 3 ; K = 18
# data 3 ; K = 19
# data 3 ; K = 20
# data 3 ; K = 21
# data 3 ; K = 22
# data 3 ; K = 23
# data 3 ; K = 24
# data 3 ; K = 25
# data 3 ; K = 26
# data 3 ; K = 27
# data 3 ; K = 28
# data 3 ; K = 29
# data 3 ; K = 30
# data 3 ; K = 31
# data 3 ; K = 32
# data 3 ; K = 33
# data 3 ; K = 34
# data 3 ; K = 35
# data 3 ; K = 36
# data 3 ; K = 37
# data 3 ; K = 38
# data 3 ; K = 39
# data 3 ; K = 40
# data 3 ; K = 41
# data 3 ; K = 42
# data 3 ; K = 43
# data 3 ; K = 44
# data 3 ; K = 45
# data 3 ; K = 46
# data 3 ; K = 47
# data 3 ; K = 48
# data 3 ; K = 49
# data 3 ; K = 50
# data 3 ; K = 51
# data 4 ; K = 1
# data 4 ; K = 2
# data 4 ; K = 3
# data 4 ; K = 4
# data 4 ; K = 5
# data 4 ; K = 6
# data 4 ; K = 7
# data 4 ; K = 8
# data 4 ; K = 9
# data 4 ; K = 10
# data 4 ; K = 11
# data 4 ; K = 12
# data 4 ; K = 13
# data 4 ; K = 14
# data 4 ; K = 15
# data 4 ; K = 16
# data 4 ; K = 17
# data 4 ; K = 18
# data 4 ; K = 19
# data 4 ; K = 20
# data 4 ; K = 21
# data 4 ; K = 22
# data 4 ; K = 23
# data 4 ; K = 24
# data 4 ; K = 25
# data 4 ; K = 26
# data 4 ; K = 27
# data 4 ; K = 28
# data 4 ; K = 29
# data 4 ; K = 30
# data 4 ; K = 31
# data 4 ; K = 32
# data 4 ; K = 33
# data 4 ; K = 34
# data 4 ; K = 35
# data 4 ; K = 36
# data 4 ; K = 37
# data 4 ; K = 38
# data 4 ; K = 39
# data 4 ; K = 40
# data 4 ; K = 41
# data 4 ; K = 42
# data 4 ; K = 43
# data 4 ; K = 44
# data 4 ; K = 45
# data 4 ; K = 46
# data 4 ; K = 47
# data 4 ; K = 48
# data 4 ; K = 49
# data 4 ; K = 50
# data 4 ; K = 51
# data 5 ; K = 1
# data 5 ; K = 2
# data 5 ; K = 3
# data 5 ; K = 4
# data 5 ; K = 5
# data 5 ; K = 6
# data 5 ; K = 7
# data 5 ; K = 8
# data 5 ; K = 9
# data 5 ; K = 10
# data 5 ; K = 11
# data 5 ; K = 12
# data 5 ; K = 13
# data 5 ; K = 14
# data 5 ; K = 15
# data 5 ; K = 16
# data 5 ; K = 17
# data 5 ; K = 18
# data 5 ; K = 19
# data 5 ; K = 20
# data 5 ; K = 21
# data 5 ; K = 22
# data 5 ; K = 23
# data 5 ; K = 24
# data 5 ; K = 25
# data 5 ; K = 26
# data 5 ; K = 27
# data 5 ; K = 28
# data 5 ; K = 29
# data 5 ; K = 30
# data 5 ; K = 31
# data 5 ; K = 32
# data 5 ; K = 33
# data 5 ; K = 34
# data 5 ; K = 35
# data 5 ; K = 36
# data 5 ; K = 37
# data 5 ; K = 38
# data 5 ; K = 39
# data 5 ; K = 40
# data 5 ; K = 41
# data 5 ; K = 42
# data 5 ; K = 43
# data 5 ; K = 44
# data 5 ; K = 45
# data 5 ; K = 46
# data 5 ; K = 47
# data 5 ; K = 48
# data 5 ; K = 49
# data 5 ; K = 50
# data 5 ; K = 51
# data 6 ; K = 1
# data 6 ; K = 2
# data 6 ; K = 3
# data 6 ; K = 4
# data 6 ; K = 5
# data 6 ; K = 6
# data 6 ; K = 7
# data 6 ; K = 8
# data 6 ; K = 9
# data 6 ; K = 10
# data 6 ; K = 11
# data 6 ; K = 12
# data 6 ; K = 13
# data 6 ; K = 14
# data 6 ; K = 15
# data 6 ; K = 16
# data 6 ; K = 17
# data 6 ; K = 18
# data 6 ; K = 19
# data 6 ; K = 20
# data 6 ; K = 21
# data 6 ; K = 22
# data 6 ; K = 23
# data 6 ; K = 24
# data 6 ; K = 25
# data 6 ; K = 26
# data 6 ; K = 27
# data 6 ; K = 28
# data 6 ; K = 29
# data 6 ; K = 30
# data 6 ; K = 31
# data 6 ; K = 32
# data 6 ; K = 33
# data 6 ; K = 34
# data 6 ; K = 35
# data 6 ; K = 36
# data 6 ; K = 37
# data 6 ; K = 38
# data 6 ; K = 39
# data 6 ; K = 40
# data 6 ; K = 41
# data 6 ; K = 42
# data 6 ; K = 43
# data 6 ; K = 44
# data 6 ; K = 45
# data 6 ; K = 46
# data 6 ; K = 47
# data 6 ; K = 48
# data 6 ; K = 49
# data 6 ; K = 50
# data 6 ; K = 51
# data 7 ; K = 1
# data 7 ; K = 2
# data 7 ; K = 3
# data 7 ; K = 4
# data 7 ; K = 5
# data 7 ; K = 6
# data 7 ; K = 7
# data 7 ; K = 8
# data 7 ; K = 9
# data 7 ; K = 10
# data 7 ; K = 11
# data 7 ; K = 12
# data 7 ; K = 13
# data 7 ; K = 14
# data 7 ; K = 15
# data 7 ; K = 16
# data 7 ; K = 17
# data 7 ; K = 18
# data 7 ; K = 19
# data 7 ; K = 20
# data 7 ; K = 21
# data 7 ; K = 22
# data 7 ; K = 23
# data 7 ; K = 24
# data 7 ; K = 25
# data 7 ; K = 26
# data 7 ; K = 27
# data 7 ; K = 28
# data 7 ; K = 29
# data 7 ; K = 30
# data 7 ; K = 31
# data 7 ; K = 32
# data 7 ; K = 33
# data 7 ; K = 34
# data 7 ; K = 35
# data 7 ; K = 36
# data 7 ; K = 37
# data 7 ; K = 38
# data 7 ; K = 39
# data 7 ; K = 40
# data 7 ; K = 41
# data 7 ; K = 42
# data 7 ; K = 43
# data 7 ; K = 44
# data 7 ; K = 45
# data 7 ; K = 46
# data 7 ; K = 47
# data 7 ; K = 48
# data 7 ; K = 49
# data 7 ; K = 50
# data 7 ; K = 51
# data 8 ; K = 1
# data 8 ; K = 2
# data 8 ; K = 3
# data 8 ; K = 4
# data 8 ; K = 5
# data 8 ; K = 6
# data 8 ; K = 7
# data 8 ; K = 8
# data 8 ; K = 9
# data 8 ; K = 10
# data 8 ; K = 11
# data 8 ; K = 12
# data 8 ; K = 13
# data 8 ; K = 14
# data 8 ; K = 15
# data 8 ; K = 16
# data 8 ; K = 17
# data 8 ; K = 18
# data 8 ; K = 19
# data 8 ; K = 20
# data 8 ; K = 21
# data 8 ; K = 22
# data 8 ; K = 23
# data 8 ; K = 24
# data 8 ; K = 25
# data 8 ; K = 26
# data 8 ; K = 27
# data 8 ; K = 28
# data 8 ; K = 29
# data 8 ; K = 30
# data 8 ; K = 31
# data 8 ; K = 32
# data 8 ; K = 33
# data 8 ; K = 34
# data 8 ; K = 35
# data 8 ; K = 36
# data 8 ; K = 37
# data 8 ; K = 38
# data 8 ; K = 39
# data 8 ; K = 40
# data 8 ; K = 41
# data 8 ; K = 42
# data 8 ; K = 43
# data 8 ; K = 44
# data 8 ; K = 45
# data 8 ; K = 46
# data 8 ; K = 47
# data 8 ; K = 48
# data 8 ; K = 49
# data 8 ; K = 50
# data 8 ; K = 51
# data 9 ; K = 1
# data 9 ; K = 2
# data 9 ; K = 3
# data 9 ; K = 4
# data 9 ; K = 5
# data 9 ; K = 6
# data 9 ; K = 7
# data 9 ; K = 8
# data 9 ; K = 9
# data 9 ; K = 10
# data 9 ; K = 11
# data 9 ; K = 12
# data 9 ; K = 13
# data 9 ; K = 14
# data 9 ; K = 15
# data 9 ; K = 16
# data 9 ; K = 17
# data 9 ; K = 18
# data 9 ; K = 19
# data 9 ; K = 20
# data 9 ; K = 21
# data 9 ; K = 22
# data 9 ; K = 23
# data 9 ; K = 24
# data 9 ; K = 25
# data 9 ; K = 26
# data 9 ; K = 27
# data 9 ; K = 28
# data 9 ; K = 29
# data 9 ; K = 30
# data 9 ; K = 31
# data 9 ; K = 32
# data 9 ; K = 33
# data 9 ; K = 34
# data 9 ; K = 35
# data 9 ; K = 36
# data 9 ; K = 37
# data 9 ; K = 38
# data 9 ; K = 39
# data 9 ; K = 40
# data 9 ; K = 41
# data 9 ; K = 42
# data 9 ; K = 43
# data 9 ; K = 44
# data 9 ; K = 45
# data 9 ; K = 46
# data 9 ; K = 47
# data 9 ; K = 48
# data 9 ; K = 49
# data 9 ; K = 50
# data 9 ; K = 51
# data 10 ; K = 1
# data 10 ; K = 2
# data 10 ; K = 3
# data 10 ; K = 4
# data 10 ; K = 5
# data 10 ; K = 6
# data 10 ; K = 7
# data 10 ; K = 8
# data 10 ; K = 9
# data 10 ; K = 10
# data 10 ; K = 11
# data 10 ; K = 12
# data 10 ; K = 13
# data 10 ; K = 14
# data 10 ; K = 15
# data 10 ; K = 16
# data 10 ; K = 17
# data 10 ; K = 18
# data 10 ; K = 19
# data 10 ; K = 20
# data 10 ; K = 21
# data 10 ; K = 22
# data 10 ; K = 23
# data 10 ; K = 24
# data 10 ; K = 25
# data 10 ; K = 26
# data 10 ; K = 27
# data 10 ; K = 28
# data 10 ; K = 29
# data 10 ; K = 30
# data 10 ; K = 31
# data 10 ; K = 32
# data 10 ; K = 33
# data 10 ; K = 34
# data 10 ; K = 35
# data 10 ; K = 36
# data 10 ; K = 37
# data 10 ; K = 38
# data 10 ; K = 39
# data 10 ; K = 40
# data 10 ; K = 41
# data 10 ; K = 42
# data 10 ; K = 43
# data 10 ; K = 44
# data 10 ; K = 45
# data 10 ; K = 46
# data 10 ; K = 47
# data 10 ; K = 48
# data 10 ; K = 49
# data 10 ; K = 50
# data 10 ; K = 51
# L =  2  is calculating...
# data 1 ; K = 1
# data 1 ; K = 2
# data 1 ; K = 3
# data 1 ; K = 4
# data 1 ; K = 5
# data 1 ; K = 6
# data 1 ; K = 7
# data 1 ; K = 8
# data 1 ; K = 9
# data 1 ; K = 10
# data 1 ; K = 11
# data 1 ; K = 12
# data 1 ; K = 13
# data 1 ; K = 14
# data 1 ; K = 15
# data 1 ; K = 16
# data 1 ; K = 17
# data 1 ; K = 18
# data 1 ; K = 19
# data 1 ; K = 20
# data 1 ; K = 21
# data 1 ; K = 22
# data 1 ; K = 23
# data 1 ; K = 24
# data 1 ; K = 25
# data 1 ; K = 26
# data 1 ; K = 27
# data 1 ; K = 28
# data 1 ; K = 29
# data 1 ; K = 30
# data 1 ; K = 31
# data 1 ; K = 32
# data 1 ; K = 33
# data 1 ; K = 34
# data 1 ; K = 35
# data 1 ; K = 36
# data 1 ; K = 37
# data 1 ; K = 38
# data 1 ; K = 39
# data 1 ; K = 40
# data 1 ; K = 41
# data 1 ; K = 42
# data 1 ; K = 43
# data 1 ; K = 44
# data 1 ; K = 45
# data 1 ; K = 46
# data 1 ; K = 47
# data 1 ; K = 48
# data 1 ; K = 49
# data 1 ; K = 50
# data 1 ; K = 51
# data 2 ; K = 1
# data 2 ; K = 2
# data 2 ; K = 3
# data 2 ; K = 4
# data 2 ; K = 5
# data 2 ; K = 6
# data 2 ; K = 7
# data 2 ; K = 8
# data 2 ; K = 9
# data 2 ; K = 10
# data 2 ; K = 11
# data 2 ; K = 12
# data 2 ; K = 13
# data 2 ; K = 14
# data 2 ; K = 15
# data 2 ; K = 16
# data 2 ; K = 17
# data 2 ; K = 18
# data 2 ; K = 19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-44e4310e204a> in <module>
#     102             print("data", n+1, "; K =", i+1)
#     103             list2 = random.choices(data,k=m)               #data 隨便可重複取m個
# --> 104             seq_k = get_s(list2)@c_m(list2)          # k_th seq
#     105 #############################################Randomized Benchmarking##########################################################
#     106 #############################################Readout##########################################################################
#
# <ipython-input-44-44e4310e204a> in c_m(c1)
#      79     a = get_s_perfect(c1)
#      80     for k in range(len(data)):
# ---> 81         b = get_perfect_unitary(data[k])
#      82         if Is_Inverse(a, b):
#      83             return get_nonperfect_unitary(data[k])
#
# <ipython-input-44-44e4310e204a> in get_perfect_unitary(seq)
#      65     p = np.identity(4)
#      66     for j in range(len(seq)):
# ---> 67         p = p@Prim_perfect[seq[j]]
#      68     return p
#      69
#
# KeyboardInterrupt:
